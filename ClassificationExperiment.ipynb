# %%
# !python3
# -*- coding:utf-8 -*-
from numpy import *
import math
import pandas as pd
import sklearn.datasets
import sklearn.model_selection
import matplotlib.pyplot as plt
from numpy import random
# %matplotlib inline

NUM_ITERATIONS = 200


def get_data(filename):
    data = sklearn.datasets.load_svmlight_file(filename)
    return data[0], data[1]


def compute_loss(X, y, theta):
    loss = 0.0
    for i in range(shape(X)[0]):
        pred = dot(X[i], theta)
        loss += max(0, y[i,0]*pred)
    loss += 0.5 * linalg.norm(theta) ** 2
    return mean(loss)/shape(X)[0]


def compute_gradient(X, y, theta,i):
    grad = zeros(shape=(1, len(theta)))
    gamma = 1
    pred = dot(X[i],theta)
    grad = max(0,1-y[i,0]*pred)*(-y[i,0]*X[i])+gamma*theta.T
    return grad.T


def SGD(X_train, y_train,X_test, y_test, ini_theta, num_iter):
    learning_rate = 0.05
    theta = ini_theta
    Ltest = []
    for i in range(num_iter):
        j = random.randint(0,shape(X_train)[0])
        theta = theta - learning_rate*compute_gradient(X_train,y_train,theta,j)
        Ltest.append(compute_loss(X_test,y_test,theta))
        print('SGD: Loss of the ', i+1, ' iteration for test:', Ltest[i])
    return Ltest


def NAG(X_train, y_train,X_test, y_test, ini_theta, num_iter):
    theta = ini_theta
    learning_rate = 0.01
    momentum = zeros(shape=(shape(theta)[0], 1))
    miu = 0.9

    Ltest = []
    for i in xrange(num_iter):
        j = random.randint(0, shape(X_train)[0])
        grad = compute_gradient(X_train, y_train, theta-miu*momentum,j)
        momentum = momentum*miu + learning_rate*grad
        theta = theta-momentum
        Ltest.append(compute_loss(X_test, y_test, theta))
        print('NAG:Loss of the ', i+1, ' iteration for test:', Ltest[i])
    return Ltest


def RMSprop(X_train, y_train, X_test, y_test, ini_theta, num_iter):
    theta = ini_theta
    learning_rate = 0.01
    g = zeros(shape=(len(theta), 1))
    eps = 1e-7
    dr = 0.95  # decay_rate
    Ltest = []

    for i in xrange(num_iter):
        j = random.randint(0, shape(X_train)[0])
        grad = compute_gradient(X_train, y_train, theta,j)
        g = dr*g +(1-dr)*square(grad)
        theta = theta - learning_rate*grad/sqrt(g+eps)
        Ltest.append(compute_loss(X_test, y_test, theta))
        print('RMSprop: Loss of the ', i+1, ' iteration for test:', Ltest[i])
    return Ltest


def Adam(X_train, y_train, X_test, y_test, ini_theta, num_iter):
    theta = ini_theta
    m = zeros(shape=(len(theta), 1))
    g = zeros(shape=(len(theta), 1))
    learning_rate = 0.01
    eps = 1e-8
    beta1 = 0.9
    beta2 = 0.999
    Ltest = []

    for i in xrange(num_iter):
        j = random.randint(0, shape(X_train)[0])
        grad = compute_gradient(X_train, y_train, theta,j)
        m = beta1*m+(1-beta1)*grad
        g = beta2*g+(1-beta2)*square(grad)
        arpha = learning_rate*sqrt(1-beta2)/(1-beta1)
        theta = theta - arpha*m/sqrt(g+eps)
        Ltest.append(compute_loss(X_test, y_test, theta))
        print('Adam: Loss of the ', i+1, ' iteration for test:', Ltest[i])
    return Ltest


def AdaDelta(X_train, y_train, X_test, y_test, ini_theta, num_iter):
    theta = ini_theta
    g = zeros(shape=(len(theta), 1))
    s = zeros(shape=(len(theta), 1))
    eps = 1e-8
    r = 0.95
    learning_rate = 50
    Ltest = []
    for i in xrange(num_iter):
        j = random.randint(0, shape(X_train)[0])
        grad = compute_gradient(X_train, y_train, theta,j)
        g = r*g+(1-r)*square(grad)
        diff_theta = -multiply(sqrt(s+eps),grad)/sqrt(g+eps)
        theta=theta+learning_rate*diff_theta
        s = r*s+(1-r)*square(diff_theta)
        Ltest.append(compute_loss(X_test, y_test, theta))
        print('AdaDelta: Loss of the ', i+1, ' iteration for test:', Ltest[i])
    return Ltest


def main():
    # Logistic regression
    X_train, y_train = get_data('./data/a9a')
    X_train = X_train.todense()
    temp = ones(shape=[shape(X_train)[0], 1], dtype=float32)
    X_train = concatenate([X_train, temp], axis=1)
    y_train = y_train.reshape(len(y_train), 1)
    for i in range(shape(y_train)[0]):
        if y_train[i,0] == -1:
            y_train[i,0] = 0

    X_test, y_test = get_data('./data/a9at')
    X_test = X_test.todense()
    X_test = append(zeros(shape=(shape(X_test)[0], 1)), X_test, 1)
    temp = ones(shape=[shape(X_test)[0], 1], dtype=float32)
    X_test = concatenate([X_test, temp], axis=1)
    y_test = y_test.reshape(len(y_test), 1)
    for i in range(shape(y_test)[0]):
        if y_test[i,0] == -1:
            y_test[i,0] = 0

    # initialize parameters
    num_iter = NUM_ITERATIONS
    initial_theta = random.rand(shape(X_test)[1])
    initial_theta = initial_theta.reshape(len(initial_theta),1)
    LSGD = SGD(X_train,y_train,X_test,y_test,initial_theta,num_iter)
    LNAG = NAG(X_train, y_train, X_test, y_test, initial_theta, num_iter)
    LRMSprop = RMSprop(X_train, y_train,X_test, y_test, initial_theta, num_iter)
    LAdam = Adam(X_train, y_train, X_test, y_test, initial_theta, num_iter)
    LAdaDelta = AdaDelta(X_train, y_train, X_test, y_test, initial_theta, num_iter)

    #  visualization
    num_iter=xrange(num_iter)
    plt.plot(num_iter, LSGD, label='SGD')
    plt.plot(num_iter, LNAG, label='NAG')
    plt.plot(num_iter,LRMSprop, label='RMSprop')
    plt.plot(num_iter, LAdam,label='Adam')
    plt.plot(num_iter, LAdaDelta,label='AdaDelta')
    plt.title('Loss for test')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    plt.legend()
    plt.show()


if __name__=='__main__':
    main()
# Out:
# ('SGD: Loss of the ', 1, ' iteration for test:', 1.934731545337558)
# ('SGD: Loss of the ', 2, ' iteration for test:', 1.8379378009746288)
# ('SGD: Loss of the ', 3, ' iteration for test:', 1.7459893176217161)
# ('SGD: Loss of the ', 4, ' iteration for test:', 1.6586432887836045)
# ('SGD: Loss of the ', 5, ' iteration for test:', 1.5756691012757131)
# ('SGD: Loss of the ', 6, ' iteration for test:', 1.4968477203924102)
# ('SGD: Loss of the ', 7, ' iteration for test:', 1.4219711063206806)
# ('SGD: Loss of the ', 8, ' iteration for test:', 1.3508416601876132)
# ('SGD: Loss of the ', 9, ' iteration for test:', 1.2832716982158627)
# ('SGD: Loss of the ', 10, ' iteration for test:', 1.219082952541533)
# ('SGD: Loss of the ', 11, ' iteration for test:', 1.1581060973253612)
# ('SGD: Loss of the ', 12, ' iteration for test:', 1.1001802988599383)
# ('SGD: Loss of the ', 13, ' iteration for test:', 1.0451527884437006)
# ('SGD: Loss of the ', 14, ' iteration for test:', 0.99287845685691523)
# ('SGD: Loss of the ', 15, ' iteration for test:', 0.9432194693355177)
# ('SGD: Loss of the ', 16, ' iteration for test:', 0.89604489999635251)
# ('SGD: Loss of the ', 17, ' iteration for test:', 0.85123038472170076)
# ('SGD: Loss of the ', 18, ' iteration for test:', 0.80865779156257755)
# ('SGD: Loss of the ', 19, ' iteration for test:', 0.76821490776890877)
# ('SGD: Loss of the ', 20, ' iteration for test:', 0.72979514260093792)
# ('SGD: Loss of the ', 21, ' iteration for test:', 0.69329724511987001)
# ('SGD: Loss of the ', 22, ' iteration for test:', 0.65862503619707902)
# ('SGD: Loss of the ', 23, ' iteration for test:', 0.62568715402043962)
# ('SGD: Loss of the ', 24, ' iteration for test:', 0.59439681241339448)
# ('SGD: Loss of the ', 25, ' iteration for test:', 0.56467157131753887)
# ('SGD: Loss of the ', 26, ' iteration for test:', 0.53643311882280575)
# ('SGD: Loss of the ', 27, ' iteration for test:', 0.50960706416087242)
# ('SGD: Loss of the ', 28, ' iteration for test:', 0.48412274110731551)
# ('SGD: Loss of the ', 29, ' iteration for test:', 0.4599130212663739)
# ('SGD: Loss of the ', 30, ' iteration for test:', 0.43691413673907226)
# ('SGD: Loss of the ', 31, ' iteration for test:', 0.41506551170087153)
# ('SGD: Loss of the ', 32, ' iteration for test:', 0.39430960243920538)
# ('SGD: Loss of the ', 33, ' iteration for test:', 0.37459174542409279)
# ('SGD: Loss of the ', 34, ' iteration for test:', 0.35586001300681736)
# ('SGD: Loss of the ', 35, ' iteration for test:', 0.33806507636214894)
# ('SGD: Loss of the ', 36, ' iteration for test:', 0.3211600753091588)
# ('SGD: Loss of the ', 37, ' iteration for test:', 0.30510049466422096)
# ('SGD: Loss of the ', 38, ' iteration for test:', 0.28984404679727893)
# ('SGD: Loss of the ', 39, ' iteration for test:', 0.27535056007922171)
# ('SGD: Loss of the ', 40, ' iteration for test:', 0.26158187292394242)
# ('SGD: Loss of the ', 41, ' iteration for test:', 0.24850173314368035)
# ('SGD: Loss of the ', 42, ' iteration for test:', 0.23607570235050346)
# ('SGD: Loss of the ', 43, ' iteration for test:', 0.22427106515024217)
# ('SGD: Loss of the ', 44, ' iteration for test:', 0.21305674288806298)
# ('SGD: Loss of the ', 45, ' iteration for test:', 0.21135198152502319)
# ('SGD: Loss of the ', 46, ' iteration for test:', 0.20078373512516873)
# ('SGD: Loss of the ', 47, ' iteration for test:', 0.19074396415935835)
# ('SGD: Loss of the ', 48, ' iteration for test:', 0.1812062387022699)
# ('SGD: Loss of the ', 49, ' iteration for test:', 0.17214545092482517)
# ('SGD: Loss of the ', 50, ' iteration for test:', 0.16353774893087947)
# ('SGD: Loss of the ', 51, ' iteration for test:', 0.15536047390778199)
# ('SGD: Loss of the ', 52, ' iteration for test:', 0.14759210042455459)
# ('SGD: Loss of the ', 53, ' iteration for test:', 0.14021217971980179)
# ('SGD: Loss of the ', 54, ' iteration for test:', 0.15575558723416003)
# ('SGD: Loss of the ', 55, ' iteration for test:', 0.1479675105261789)
# ('SGD: Loss of the ', 56, ' iteration for test:', 0.15429801188826592)
# ('SGD: Loss of the ', 57, ' iteration for test:', 0.14658283631957422)
# ('SGD: Loss of the ', 58, ' iteration for test:', 0.139253446339311)
# ('SGD: Loss of the ', 59, ' iteration for test:', 0.13229055005407742)
# ('SGD: Loss of the ', 60, ' iteration for test:', 0.12567582042001255)
# ('SGD: Loss of the ', 61, ' iteration for test:', 0.11939184697545828)
# ('SGD: Loss of the ', 62, ' iteration for test:', 0.11342208998942845)
# ('SGD: Loss of the ', 63, ' iteration for test:', 0.10775083690483173)
# ('SGD: Loss of the ', 64, ' iteration for test:', 0.12939620492064738)
# ('SGD: Loss of the ', 65, ' iteration for test:', 0.122926222914315)
# ('SGD: Loss of the ', 66, ' iteration for test:', 0.1167797567549287)
# ('SGD: Loss of the ', 67, ' iteration for test:', 0.11094062901734454)
# ('SGD: Loss of the ', 68, ' iteration for test:', 0.10539347130687396)
# ('SGD: Loss of the ', 69, ' iteration for test:', 0.10012368379223779)
# ('SGD: Loss of the ', 70, ' iteration for test:', 0.11543929696879736)
# ('SGD: Loss of the ', 71, ' iteration for test:', 0.10966719548727911)
# ('SGD: Loss of the ', 72, ' iteration for test:', 0.10418371240156202)
# ('SGD: Loss of the ', 73, ' iteration for test:', 0.098974415492987439)
# ('SGD: Loss of the ', 74, ' iteration for test:', 0.1100632024039552)
# ('SGD: Loss of the ', 75, ' iteration for test:', 0.11662307014774782)
# ('SGD: Loss of the ', 76, ' iteration for test:', 0.11079176914288662)
# ('SGD: Loss of the ', 77, ' iteration for test:', 0.10525204756927245)
# ('SGD: Loss of the ', 78, ' iteration for test:', 0.099989325053194869)
# ('SGD: Loss of the ', 79, ' iteration for test:', 0.1120318601742767)
# ('SGD: Loss of the ', 80, ' iteration for test:', 0.11798792322546003)
# ('SGD: Loss of the ', 81, ' iteration for test:', 0.11208837742848152)
# ('SGD: Loss of the ', 82, ' iteration for test:', 0.10648382351083273)
# ('SGD: Loss of the ', 83, ' iteration for test:', 0.1103564260840878)
# ('SGD: Loss of the ', 84, ' iteration for test:', 0.10483847104019413)
# ('SGD: Loss of the ', 85, ' iteration for test:', 0.099596426788114922)
# ('SGD: Loss of the ', 86, ' iteration for test:', 0.094616496516896686)
# ('SGD: Loss of the ', 87, ' iteration for test:', 0.0898855733800909)
# ('SGD: Loss of the ', 88, ' iteration for test:', 0.085391205985443849)
# ('SGD: Loss of the ', 89, ' iteration for test:', 0.097178695617120073)
# ('SGD: Loss of the ', 90, ' iteration for test:', 0.092319653788918266)
# ('SGD: Loss of the ', 91, ' iteration for test:', 0.087703574489242445)
# ('SGD: Loss of the ', 92, ' iteration for test:', 0.083318308574047817)
# ('SGD: Loss of the ', 93, ' iteration for test:', 0.079152314455709374)
# ('SGD: Loss of the ', 94, ' iteration for test:', 0.075194627715527568)
# ('SGD: Loss of the ', 95, ' iteration for test:', 0.071434832236550727)
# ('SGD: Loss of the ', 96, ' iteration for test:', 0.067863032780609928)
# ('SGD: Loss of the ', 97, ' iteration for test:', 0.064469828937267201)
# ('SGD: Loss of the ', 98, ' iteration for test:', 0.083083989492505159)
# ('SGD: Loss of the ', 99, ' iteration for test:', 0.078929701137300162)
# ('SGD: Loss of the ', 100, ' iteration for test:', 0.074983135865711273)
# ('SGD: Loss of the ', 101, ' iteration for test:', 0.071233906678638326)
# ('SGD: Loss of the ', 102, ' iteration for test:', 0.067672146009312636)
# ('SGD: Loss of the ', 103, ' iteration for test:', 0.082651047625797114)
# ('SGD: Loss of the ', 104, ' iteration for test:', 0.078518402275827875)
# ('SGD: Loss of the ', 105, ' iteration for test:', 0.087703439328168792)
# ('SGD: Loss of the ', 106, ' iteration for test:', 0.094826980576904155)
# ('SGD: Loss of the ', 107, ' iteration for test:', 0.093544763138163831)
# ('SGD: Loss of the ', 108, ' iteration for test:', 0.088867407009225116)
# ('SGD: Loss of the ', 109, ' iteration for test:', 0.08442393018900593)
# ('SGD: Loss of the ', 110, ' iteration for test:', 0.090268880710025187)
# ('SGD: Loss of the ', 111, ' iteration for test:', 0.085755323664686675)
# ('SGD: Loss of the ', 112, ' iteration for test:', 0.081467455490074711)
# ('SGD: Loss of the ', 113, ' iteration for test:', 0.077393990668352564)
# ('SGD: Loss of the ', 114, ' iteration for test:', 0.09405689448370598)
# ('SGD: Loss of the ', 115, ' iteration for test:', 0.089353935986302799)
# ('SGD: Loss of the ', 116, ' iteration for test:', 0.084886136506658563)
# ('SGD: Loss of the ', 117, ' iteration for test:', 0.080641737012328962)
# ('SGD: Loss of the ', 118, ' iteration for test:', 0.076609566527942666)
# ('SGD: Loss of the ', 119, ' iteration for test:', 0.072779012722068173)
# ('SGD: Loss of the ', 120, ' iteration for test:', 0.06913999396573671)
# ('SGD: Loss of the ', 121, ' iteration for test:', 0.065682932788943924)
# ('SGD: Loss of the ', 122, ' iteration for test:', 0.06239873066514507)
# ('SGD: Loss of the ', 123, ' iteration for test:', 0.080054727277675014)
# ('SGD: Loss of the ', 124, ' iteration for test:', 0.076051900922217641)
# ('SGD: Loss of the ', 125, ' iteration for test:', 0.072249224658711697)
# ('SGD: Loss of the ', 126, ' iteration for test:', 0.068636690127076933)
# ('SGD: Loss of the ', 127, ' iteration for test:', 0.065204789468646912)
# ('SGD: Loss of the ', 128, ' iteration for test:', 0.079562155594604472)
# ('SGD: Loss of the ', 129, ' iteration for test:', 0.075583948840096449)
# ('SGD: Loss of the ', 130, ' iteration for test:', 0.071804662073355313)
# ('SGD: Loss of the ', 131, ' iteration for test:', 0.087455710994476174)
# ('SGD: Loss of the ', 132, ' iteration for test:', 0.083082813569791525)
# ('SGD: Loss of the ', 133, ' iteration for test:', 0.078928571924149593)
# ('SGD: Loss of the ', 134, ' iteration for test:', 0.088735346026466322)
# ('SGD: Loss of the ', 135, ' iteration for test:', 0.084298464201606721)
# ('SGD: Loss of the ', 136, ' iteration for test:', 0.087267870145523382)
# ('SGD: Loss of the ', 137, ' iteration for test:', 0.08290436555030363)
# ('SGD: Loss of the ', 138, ' iteration for test:', 0.078759047015919847)
# ('SGD: Loss of the ', 139, ' iteration for test:', 0.1008652962223557)
# ('SGD: Loss of the ', 140, ' iteration for test:', 0.095821902486500007)
# ('SGD: Loss of the ', 141, ' iteration for test:', 0.091030691007598988)
# ('SGD: Loss of the ', 142, ' iteration for test:', 0.086479051447214517)
# ('SGD: Loss of the ', 143, ' iteration for test:', 0.082155004103323992)
# ('SGD: Loss of the ', 144, ' iteration for test:', 0.078047168366852909)
# ('SGD: Loss of the ', 145, ' iteration for test:', 0.074144732756507375)
# ('SGD: Loss of the ', 146, ' iteration for test:', 0.070437426452899063)
# ('SGD: Loss of the ', 147, ' iteration for test:', 0.066915492256885284)
# ('SGD: Loss of the ', 148, ' iteration for test:', 0.063569660900825525)
# ('SGD: Loss of the ', 149, ' iteration for test:', 0.060391126645032545)
# ('SGD: Loss of the ', 150, ' iteration for test:', 0.057371524095077266)
# ('SGD: Loss of the ', 151, ' iteration for test:', 0.077293849918388918)
# ('SGD: Loss of the ', 152, ' iteration for test:', 0.073429073816848545)
# ('SGD: Loss of the ', 153, ' iteration for test:', 0.069757544671932847)
# ('SGD: Loss of the ', 154, ' iteration for test:', 0.066269599341035379)
# ('SGD: Loss of the ', 155, ' iteration for test:', 0.06295605791616958)
# ('SGD: Loss of the ', 156, ' iteration for test:', 0.059808199554683764)
# ('SGD: Loss of the ', 157, ' iteration for test:', 0.084428101338075143)
# ('SGD: Loss of the ', 158, ' iteration for test:', 0.080206600691722391)
# ('SGD: Loss of the ', 159, ' iteration for test:', 0.076196184396683742)
# ('SGD: Loss of the ', 160, ' iteration for test:', 0.089164768932863611)
# ('SGD: Loss of the ', 161, ' iteration for test:', 0.084706421358628659)
# ('SGD: Loss of the ', 162, ' iteration for test:', 0.080471001803045589)
# ('SGD: Loss of the ', 163, ' iteration for test:', 0.089351752224794218)
# ('SGD: Loss of the ', 164, ' iteration for test:', 0.08488405425750481)
# ('SGD: Loss of the ', 165, ' iteration for test:', 0.080639751948294855)
# ('SGD: Loss of the ', 166, ' iteration for test:', 0.088170277218801163)
# ('SGD: Loss of the ', 167, ' iteration for test:', 0.083761656649034885)
# ('SGD: Loss of the ', 168, ' iteration for test:', 0.079573477511867163)
# ('SGD: Loss of the ', 169, ' iteration for test:', 0.07559471672126819)
# ('SGD: Loss of the ', 170, ' iteration for test:', 0.071814902444411244)
# ('SGD: Loss of the ', 171, ' iteration for test:', 0.068224086529375477)
# ('SGD: Loss of the ', 172, ' iteration for test:', 0.064812818312390427)
# ('SGD: Loss of the ', 173, ' iteration for test:', 0.061572119735580334)
# ('SGD: Loss of the ', 174, ' iteration for test:', 0.058493461709576533)
# ('SGD: Loss of the ', 175, ' iteration for test:', 0.055568741658697483)
# ('SGD: Loss of the ', 176, ' iteration for test:', 0.052790262189488964)
# ('SGD: Loss of the ', 177, ' iteration for test:', 0.073185618703706018)
# ('SGD: Loss of the ', 178, ' iteration for test:', 0.091103824812463707)
# ('SGD: Loss of the ', 179, ' iteration for test:', 0.08654851281738131)
# ('SGD: Loss of the ', 180, ' iteration for test:', 0.08222097819561279)
# ('SGD: Loss of the ', 181, ' iteration for test:', 0.09943957545156222)
# ('SGD: Loss of the ', 182, ' iteration for test:', 0.094467465719855676)
# ('SGD: Loss of the ', 183, ' iteration for test:', 0.10016112875083465)
# ('SGD: Loss of the ', 184, ' iteration for test:', 0.10153611687468553)
# ('SGD: Loss of the ', 185, ' iteration for test:', 0.096459176215545769)
# ('SGD: Loss of the ', 186, ' iteration for test:', 0.091636095733864956)
# ('SGD: Loss of the ', 187, ' iteration for test:', 0.1074932542757977)
# ('SGD: Loss of the ', 188, ' iteration for test:', 0.10211845244067445)
# ('SGD: Loss of the ', 189, ' iteration for test:', 0.097012404261637292)
# ('SGD: Loss of the ', 190, ' iteration for test:', 0.092161670733360582)
# ('SGD: Loss of the ', 191, ' iteration for test:', 0.087553484929728628)
# ('SGD: Loss of the ', 192, ' iteration for test:', 0.097297496944074857)
# ('SGD: Loss of the ', 193, ' iteration for test:', 0.092432506077332055)
# ('SGD: Loss of the ', 194, ' iteration for test:', 0.087810776065831431)
# ('SGD: Loss of the ', 195, ' iteration for test:', 0.083420142763900362)
# ('SGD: Loss of the ', 196, ' iteration for test:', 0.079249050340683053)
# ('SGD: Loss of the ', 197, ' iteration for test:', 0.0752865208539161)
# ('SGD: Loss of the ', 198, ' iteration for test:', 0.071522125346036677)
# ('SGD: Loss of the ', 199, ' iteration for test:', 0.091503283632383484)
# ('SGD: Loss of the ', 200, ' iteration for test:', 0.086928017613590286)
# ('NAG:Loss of the ', 1, ' iteration for test:', 2.0162467342884298)
# ('NAG:Loss of the ', 2, ' iteration for test:', 1.9779136851576069)
# ('NAG:Loss of the ', 3, ' iteration for test:', 1.9239685783383083)
# ('NAG:Loss of the ', 4, ' iteration for test:', 1.8566541884268732)
# ('NAG:Loss of the ', 5, ' iteration for test:', 1.7781027194545103)
# ('NAG:Loss of the ', 6, ' iteration for test:', 1.6903264074835782)
# ('NAG:Loss of the ', 7, ' iteration for test:', 1.5952103727929592)
# ('NAG:Loss of the ', 8, ' iteration for test:', 1.4945075462786677)
# ('NAG:Loss of the ', 9, ' iteration for test:', 1.3898354925295122)
# ('NAG:Loss of the ', 10, ' iteration for test:', 1.2826749520737424)
# ('NAG:Loss of the ', 11, ' iteration for test:', 1.1743699272652977)
# ('NAG:Loss of the ', 12, ' iteration for test:', 1.0661291399295942)
# ('NAG:Loss of the ', 13, ' iteration for test:', 0.95902869397252499)
# ('NAG:Loss of the ', 14, ' iteration for test:', 0.85401578244062248)
# ('NAG:Loss of the ', 15, ' iteration for test:', 0.75191328578748307)
# ('NAG:Loss of the ', 16, ' iteration for test:', 0.6534251161512834)
# ('NAG:Loss of the ', 17, ' iteration for test:', 0.55914217109608455)
# ('NAG:Loss of the ', 18, ' iteration for test:', 0.46954876934896639)
# ('NAG:Loss of the ', 19, ' iteration for test:', 0.38502945042491871)
# ('NAG:Loss of the ', 20, ' iteration for test:', 0.30587602953845627)
# ('NAG:Loss of the ', 21, ' iteration for test:', 0.23526427420425741)
# ('NAG:Loss of the ', 22, ' iteration for test:', 0.16999936221892448)
# ('NAG:Loss of the ', 23, ' iteration for test:', 0.11015076185803979)
# ('NAG:Loss of the ', 24, ' iteration for test:', 0.062878585188690717)
# ('NAG:Loss of the ', 25, ' iteration for test:', 0.020131843781082428)
# ('NAG:Loss of the ', 26, ' iteration for test:', 3.1641629067876482e-05)
# ('NAG:Loss of the ', 27, ' iteration for test:', 2.1955498059292279e-06)
# ('NAG:Loss of the ', 28, ' iteration for test:', 4.2235995943183316e-06)
# ('NAG:Loss of the ', 29, ' iteration for test:', 6.3214134102104973e-06)
# ('NAG:Loss of the ', 30, ' iteration for test:', 8.4736081837765151e-06)
# ('NAG:Loss of the ', 31, ' iteration for test:', 1.0418860887626159e-05)
# ('NAG:Loss of the ', 32, ' iteration for test:', 2.2591584141083951e-05)
# ('NAG:Loss of the ', 33, ' iteration for test:', 0.00015482693458545769)
# ('NAG:Loss of the ', 34, ' iteration for test:', 0.00065379222358252743)
# ('NAG:Loss of the ', 35, ' iteration for test:', 0.0016154293589391024)
# ('NAG:Loss of the ', 36, ' iteration for test:', 0.0043860435377656862)
# ('NAG:Loss of the ', 37, ' iteration for test:', 0.0090133771963489782)
# ('NAG:Loss of the ', 38, ' iteration for test:', 0.016725280980052912)
# ('NAG:Loss of the ', 39, ' iteration for test:', 0.026149476538355705)
# ('NAG:Loss of the ', 40, ' iteration for test:', 0.036197428658255711)
# ('NAG:Loss of the ', 41, ' iteration for test:', 0.046066454184117207)
# ('NAG:Loss of the ', 42, ' iteration for test:', 0.055338551107344446)
# ('NAG:Loss of the ', 43, ' iteration for test:', 0.063585317838574476)
# ('NAG:Loss of the ', 44, ' iteration for test:', 0.070692993237295831)
# ('NAG:Loss of the ', 45, ' iteration for test:', 0.07662062643930577)
# ('NAG:Loss of the ', 46, ' iteration for test:', 0.081530632287792795)
# ('NAG:Loss of the ', 47, ' iteration for test:', 0.08522250691260784)
# ('NAG:Loss of the ', 48, ' iteration for test:', 0.087737784968680607)
# ('NAG:Loss of the ', 49, ' iteration for test:', 0.08915417209013092)
# ('NAG:Loss of the ', 50, ' iteration for test:', 0.089543416324949276)
# ('NAG:Loss of the ', 51, ' iteration for test:', 0.089002442500832751)
# ('NAG:Loss of the ', 52, ' iteration for test:', 0.087631676580359488)
# ('NAG:Loss of the ', 53, ' iteration for test:', 0.085534042598160623)
# ('NAG:Loss of the ', 54, ' iteration for test:', 0.08280975487992405)
# ('NAG:Loss of the ', 55, ' iteration for test:', 0.079554368374612813)
# ('NAG:Loss of the ', 56, ' iteration for test:', 0.075858331130596965)
# ('NAG:Loss of the ', 57, ' iteration for test:', 0.074006303151398528)
# ('NAG:Loss of the ', 58, ' iteration for test:', 0.075612665522323042)
# ('NAG:Loss of the ', 59, ' iteration for test:', 0.076287841053548688)
# ('NAG:Loss of the ', 60, ' iteration for test:', 0.076126573903024769)
# ('NAG:Loss of the ', 61, ' iteration for test:', 0.075221645736091719)
# ('NAG:Loss of the ', 62, ' iteration for test:', 0.073663161837151284)
# ('NAG:Loss of the ', 63, ' iteration for test:', 0.071537941794840812)
# ('NAG:Loss of the ', 64, ' iteration for test:', 0.068929009454938281)
# ('NAG:Loss of the ', 65, ' iteration for test:', 0.065915176421221369)
# ('NAG:Loss of the ', 66, ' iteration for test:', 0.062570713072746684)
# ('NAG:Loss of the ', 67, ' iteration for test:', 0.058965100848469711)
# ('NAG:Loss of the ', 68, ' iteration for test:', 0.055162859418751986)
# ('NAG:Loss of the ', 69, ' iteration for test:', 0.051223442309962716)
# ('NAG:Loss of the ', 70, ' iteration for test:', 0.047201194565181334)
# ('NAG:Loss of the ', 71, ' iteration for test:', 0.043145366103090214)
# ('NAG:Loss of the ', 72, ' iteration for test:', 0.046266799532780553)
# ('NAG:Loss of the ', 73, ' iteration for test:', 0.056011804191773359)
# ('NAG:Loss of the ', 74, ' iteration for test:', 0.070846290836418357)
# ('NAG:Loss of the ', 75, ' iteration for test:', 0.083355463183874698)
# ('NAG:Loss of the ', 76, ' iteration for test:', 0.093667651166104732)
# ('NAG:Loss of the ', 77, ' iteration for test:', 0.1019191733352372)
# ('NAG:Loss of the ', 78, ' iteration for test:', 0.10825210251581958)
# ('NAG:Loss of the ', 79, ' iteration for test:', 0.11281221732160233)
# ('NAG:Loss of the ', 80, ' iteration for test:', 0.11574713980885547)
# ('NAG:Loss of the ', 81, ' iteration for test:', 0.11720465764125571)
# ('NAG:Loss of the ', 82, ' iteration for test:', 0.11733122746715612)
# ('NAG:Loss of the ', 83, ' iteration for test:', 0.11778716592380128)
# ('NAG:Loss of the ', 84, ' iteration for test:', 0.11701550117042656)
# ('NAG:Loss of the ', 85, ' iteration for test:', 0.11717722813547282)
# ('NAG:Loss of the ', 86, ' iteration for test:', 0.11614952090001551)
# ('NAG:Loss of the ', 87, ' iteration for test:', 0.11407230602118218)
# ('NAG:Loss of the ', 88, ' iteration for test:', 0.111080754749524)
# ('NAG:Loss of the ', 89, ' iteration for test:', 0.10730444914033804)
# ('NAG:Loss of the ', 90, ' iteration for test:', 0.1028666950204593)
# ('NAG:Loss of the ', 91, ' iteration for test:', 0.10076797324955142)
# ('NAG:Loss of the ', 92, ' iteration for test:', 0.097890315273332654)
# ('NAG:Loss of the ', 93, ' iteration for test:', 0.096730140149336036)
# ('NAG:Loss of the ', 94, ' iteration for test:', 0.094729107833874629)
# ('NAG:Loss of the ', 95, ' iteration for test:', 0.09199888295721835)
# ('NAG:Loss of the ', 96, ' iteration for test:', 0.088646251400988321)
# ('NAG:Loss of the ', 97, ' iteration for test:', 0.08477258395612737)
# ('NAG:Loss of the ', 98, ' iteration for test:', 0.080473412634072677)
# ('NAG:Loss of the ', 99, ' iteration for test:', 0.078756553475294547)
# ('NAG:Loss of the ', 100, ' iteration for test:', 0.076439257931500609)
# ('NAG:Loss of the ', 101, ' iteration for test:', 0.073610146733496279)
# ('NAG:Loss of the ', 102, ' iteration for test:', 0.070353299682703971)
# ('NAG:Loss of the ', 103, ' iteration for test:', 0.066747909633495861)
# ('NAG:Loss of the ', 104, ' iteration for test:', 0.062868023087016223)
# ('NAG:Loss of the ', 105, ' iteration for test:', 0.058782360549978804)
# ('NAG:Loss of the ', 106, ' iteration for test:', 0.054554209759574403)
# ('NAG:Loss of the ', 107, ' iteration for test:', 0.050241384898213254)
# ('NAG:Loss of the ', 108, ' iteration for test:', 0.045896245010916707)
# ('NAG:Loss of the ', 109, ' iteration for test:', 0.047261494929841948)
# ('NAG:Loss of the ', 110, ' iteration for test:', 0.048005331173327608)
# ('NAG:Loss of the ', 111, ' iteration for test:', 0.055373824168264786)
# ('NAG:Loss of the ', 112, ' iteration for test:', 0.0656232575723978)
# ('NAG:Loss of the ', 113, ' iteration for test:', 0.07409932157407198)
# ('NAG:Loss of the ', 114, ' iteration for test:', 0.080910529428623451)
# ('NAG:Loss of the ', 115, ' iteration for test:', 0.086170219884069532)
# ('NAG:Loss of the ', 116, ' iteration for test:', 0.08999489738570253)
# ('NAG:Loss of the ', 117, ' iteration for test:', 0.092502721475419436)
# ('NAG:Loss of the ', 118, ' iteration for test:', 0.09554198061661312)
# ('NAG:Loss of the ', 119, ' iteration for test:', 0.097294517901914554)
# ('NAG:Loss of the ', 120, ' iteration for test:', 0.097883056368967616)
# ('NAG:Loss of the ', 121, ' iteration for test:', 0.097428584810147656)
# ('NAG:Loss of the ', 122, ' iteration for test:', 0.096049336376300351)
# ('NAG:Loss of the ', 123, ' iteration for test:', 0.093859906111828068)
# ('NAG:Loss of the ', 124, ' iteration for test:', 0.090970501111354893)
# ('NAG:Loss of the ', 125, ' iteration for test:', 0.087486316346048101)
# ('NAG:Loss of the ', 126, ' iteration for test:', 0.083507028705513006)
# ('NAG:Loss of the ', 127, ' iteration for test:', 0.079126401428933457)
# ('NAG:Loss of the ', 128, ' iteration for test:', 0.076950344472676652)
# ('NAG:Loss of the ', 129, ' iteration for test:', 0.074241961203797738)
# ('NAG:Loss of the ', 130, ' iteration for test:', 0.071086361165668785)
# ('NAG:Loss of the ', 131, ' iteration for test:', 0.074305658530092827)
# ('NAG:Loss of the ', 132, ' iteration for test:', 0.076430997448807617)
# ('NAG:Loss of the ', 133, ' iteration for test:', 0.07756036226561977)
# ('NAG:Loss of the ', 134, ' iteration for test:', 0.077791018068869663)
# ('NAG:Loss of the ', 135, ' iteration for test:', 0.077218616215707248)
# ('NAG:Loss of the ', 136, ' iteration for test:', 0.075936413502424194)
# ('NAG:Loss of the ', 137, ' iteration for test:', 0.074034600406942791)
# ('NAG:Loss of the ', 138, ' iteration for test:', 0.071599733235739066)
# ('NAG:Loss of the ', 139, ' iteration for test:', 0.068714264530322908)
# ('NAG:Loss of the ', 140, ' iteration for test:', 0.065456165719853604)
# ('NAG:Loss of the ', 141, ' iteration for test:', 0.061898635738467843)
# ('NAG:Loss of the ', 142, ' iteration for test:', 0.066012178178537731)
# ('NAG:Loss of the ', 143, ' iteration for test:', 0.069017231609610291)
# ('NAG:Loss of the ', 144, ' iteration for test:', 0.071004565585207222)
# ('NAG:Loss of the ', 145, ' iteration for test:', 0.072065234289392516)
# ('NAG:Loss of the ', 146, ' iteration for test:', 0.072289634804076811)
# ('NAG:Loss of the ', 147, ' iteration for test:', 0.071766674591556001)
# ('NAG:Loss of the ', 148, ' iteration for test:', 0.070583044619908733)
# ('NAG:Loss of the ', 149, ' iteration for test:', 0.068822593890377273)
# ('NAG:Loss of the ', 150, ' iteration for test:', 0.072589880606791876)
# ('NAG:Loss of the ', 151, ' iteration for test:', 0.075220638664212497)
# ('NAG:Loss of the ', 152, ' iteration for test:', 0.082163747808703655)
# ('NAG:Loss of the ', 153, ' iteration for test:', 0.087528442642131235)
# ('NAG:Loss of the ', 154, ' iteration for test:', 0.091433109921086705)
# ('NAG:Loss of the ', 155, ' iteration for test:', 0.093997835730342733)
# ('NAG:Loss of the ', 156, ' iteration for test:', 0.095343019037357646)
# ('NAG:Loss of the ', 157, ' iteration for test:', 0.095588133215761178)
# ('NAG:Loss of the ', 158, ' iteration for test:', 0.094850631812523303)
# ('NAG:Loss of the ', 159, ' iteration for test:', 0.093244993793631881)
# ('NAG:Loss of the ', 160, ' iteration for test:', 0.090881902624395133)
# ('NAG:Loss of the ', 161, ' iteration for test:', 0.087867552814201166)
# ('NAG:Loss of the ', 162, ' iteration for test:', 0.087961337114776758)
# ('NAG:Loss of the ', 163, ' iteration for test:', 0.087165275457859168)
# ('NAG:Loss of the ', 164, ' iteration for test:', 0.088635066356807984)
# ('NAG:Loss of the ', 165, ' iteration for test:', 0.089058288280900233)
# ('NAG:Loss of the ', 166, ' iteration for test:', 0.09270810551193491)
# ('NAG:Loss of the ', 167, ' iteration for test:', 0.095033007153737956)
# ('NAG:Loss of the ', 168, ' iteration for test:', 0.096154152736941251)
# ('NAG:Loss of the ', 169, ' iteration for test:', 0.096191535575396711)
# ('NAG:Loss of the ', 170, ' iteration for test:', 0.096739095689346771)
# ('NAG:Loss of the ', 171, ' iteration for test:', 0.096259561371653757)
# ('NAG:Loss of the ', 172, ' iteration for test:', 0.096013483597484614)
# ('NAG:Loss of the ', 173, ' iteration for test:', 0.094834071144353591)
# ('NAG:Loss of the ', 174, ' iteration for test:', 0.092834851392667325)
# ('NAG:Loss of the ', 175, ' iteration for test:', 0.090125176685988961)
# ('NAG:Loss of the ', 176, ' iteration for test:', 0.086809585507774567)
# ('NAG:Loss of the ', 177, ' iteration for test:', 0.086659659120908866)
# ('NAG:Loss of the ', 178, ' iteration for test:', 0.085659462028967848)
# ('NAG:Loss of the ', 179, ' iteration for test:', 0.083911676147140013)
# ('NAG:Loss of the ', 180, ' iteration for test:', 0.081515267842713679)
# ('NAG:Loss of the ', 181, ' iteration for test:', 0.078564902989086707)
# ('NAG:Loss of the ', 182, ' iteration for test:', 0.077865483406214256)
# ('NAG:Loss of the ', 183, ' iteration for test:', 0.076463631209886432)
# ('NAG:Loss of the ', 184, ' iteration for test:', 0.074449930905643738)
# ('NAG:Loss of the ', 185, ' iteration for test:', 0.071911212412292203)
# ('NAG:Loss of the ', 186, ' iteration for test:', 0.068930091792076639)
# ('NAG:Loss of the ', 187, ' iteration for test:', 0.065584604212902117)
# ('NAG:Loss of the ', 188, ' iteration for test:', 0.066226202523743977)
# ('NAG:Loss of the ', 189, ' iteration for test:', 0.070356685801929983)
# ('NAG:Loss of the ', 190, ' iteration for test:', 0.073333383821269221)
# ('NAG:Loss of the ', 191, ' iteration for test:', 0.075252284646608783)
# ('NAG:Loss of the ', 192, ' iteration for test:', 0.079413979625039571)
# ('NAG:Loss of the ', 193, ' iteration for test:', 0.087892463213328609)
# ('NAG:Loss of the ', 194, ' iteration for test:', 0.094567875706579929)
# ('NAG:Loss of the ', 195, ' iteration for test:', 0.099569984114176072)
# ('NAG:Loss of the ', 196, ' iteration for test:', 0.10303114778977453)
# ('NAG:Loss of the ', 197, ' iteration for test:', 0.10508471173506279)
# ('NAG:Loss of the ', 198, ' iteration for test:', 0.10586356517119573)
# ('NAG:Loss of the ', 199, ' iteration for test:', 0.10549886179852291)
# ('NAG:Loss of the ', 200, ' iteration for test:', 0.10647887604470849)
# ('RMSprop: Loss of the ', 1, ' iteration for test:', 1.8786102952089878)
# ('RMSprop: Loss of the ', 2, ' iteration for test:', 1.7764328944524306)
# ('RMSprop: Loss of the ', 3, ' iteration for test:', 1.6964427963133837)
# ('RMSprop: Loss of the ', 4, ' iteration for test:', 1.6292235649895803)
# ('RMSprop: Loss of the ', 5, ' iteration for test:', 1.5703169439481803)
# ('RMSprop: Loss of the ', 6, ' iteration for test:', 1.5173701618445905)
# ('RMSprop: Loss of the ', 7, ' iteration for test:', 1.468938183026014)
# ('RMSprop: Loss of the ', 8, ' iteration for test:', 1.4240750327689793)
# ('RMSprop: Loss of the ', 9, ' iteration for test:', 1.3821214027063862)
# ('RMSprop: Loss of the ', 10, ' iteration for test:', 1.3425992013152968)
# ('RMSprop: Loss of the ', 11, ' iteration for test:', 1.305149491137727)
# ('RMSprop: Loss of the ', 12, ' iteration for test:', 1.2694956246854499)
# ('RMSprop: Loss of the ', 13, ' iteration for test:', 1.2354194533082237)
# ('RMSprop: Loss of the ', 14, ' iteration for test:', 1.2027456900298321)
# ('RMSprop: Loss of the ', 15, ' iteration for test:', 1.1713311252967635)
# ('RMSprop: Loss of the ', 16, ' iteration for test:', 1.14105706482665)
# ('RMSprop: Loss of the ', 17, ' iteration for test:', 1.1118238542222032)
# ('RMSprop: Loss of the ', 18, ' iteration for test:', 1.0835468613352301)
# ('RMSprop: Loss of the ', 19, ' iteration for test:', 1.0561534582773231)
# ('RMSprop: Loss of the ', 20, ' iteration for test:', 1.029580732077193)
# ('RMSprop: Loss of the ', 21, ' iteration for test:', 1.0037737158009821)
# ('RMSprop: Loss of the ', 22, ' iteration for test:', 0.97868401308098196)
# ('RMSprop: Loss of the ', 23, ' iteration for test:', 0.95426871145696879)
# ('RMSprop: Loss of the ', 24, ' iteration for test:', 0.93048952123526874)
# ('RMSprop: Loss of the ', 25, ' iteration for test:', 0.90731208212807857)
# ('RMSprop: Loss of the ', 26, ' iteration for test:', 0.88470540548386412)
# ('RMSprop: Loss of the ', 27, ' iteration for test:', 0.86264141674755168)
# ('RMSprop: Loss of the ', 28, ' iteration for test:', 0.84109458312927321)
# ('RMSprop: Loss of the ', 29, ' iteration for test:', 0.82004160133224413)
# ('RMSprop: Loss of the ', 30, ' iteration for test:', 0.7994611421195803)
# ('RMSprop: Loss of the ', 31, ' iteration for test:', 0.77933362868935252)
# ('RMSprop: Loss of the ', 32, ' iteration for test:', 0.75964105795057701)
# ('RMSprop: Loss of the ', 33, ' iteration for test:', 0.7403668341362224)
# ('RMSprop: Loss of the ', 34, ' iteration for test:', 0.72149564553293222)
# ('RMSprop: Loss of the ', 35, ' iteration for test:', 0.70301332495089963)
# ('RMSprop: Loss of the ', 36, ' iteration for test:', 0.6849067804539658)
# ('RMSprop: Loss of the ', 37, ' iteration for test:', 0.66716384221968961)
# ('RMSprop: Loss of the ', 38, ' iteration for test:', 0.64977329126796157)
# ('RMSprop: Loss of the ', 39, ' iteration for test:', 0.63272457541522231)
# ('RMSprop: Loss of the ', 40, ' iteration for test:', 0.6160081579607789)
# ('RMSprop: Loss of the ', 41, ' iteration for test:', 0.59961460441754566)
# ('RMSprop: Loss of the ', 42, ' iteration for test:', 0.58353635009392846)
# ('RMSprop: Loss of the ', 43, ' iteration for test:', 0.56776360329146358)
# ('RMSprop: Loss of the ', 44, ' iteration for test:', 0.55229363529283393)
# ('RMSprop: Loss of the ', 45, ' iteration for test:', 0.53710838038042463)
# ('RMSprop: Loss of the ', 46, ' iteration for test:', 0.52222992136850077)
# ('RMSprop: Loss of the ', 47, ' iteration for test:', 0.50757834378678035)
# ('RMSprop: Loss of the ', 48, ' iteration for test:', 0.49333368726474425)
# ('RMSprop: Loss of the ', 49, ' iteration for test:', 0.47910800005955373)
# ('RMSprop: Loss of the ', 50, ' iteration for test:', 0.46548117913467674)
# ('RMSprop: Loss of the ', 51, ' iteration for test:', 0.45178726879240161)
# ('RMSprop: Loss of the ', 52, ' iteration for test:', 0.43860196575697935)
# ('RMSprop: Loss of the ', 53, ' iteration for test:', 0.42550644865934295)
# ('RMSprop: Loss of the ', 54, ' iteration for test:', 0.41275064364346686)
# ('RMSprop: Loss of the ', 55, ' iteration for test:', 0.40018727310413871)
# ('RMSprop: Loss of the ', 56, ' iteration for test:', 0.38789571882047591)
# ('RMSprop: Loss of the ', 57, ' iteration for test:', 0.37582233502878409)
# ('RMSprop: Loss of the ', 58, ' iteration for test:', 0.36399718919406721)
# ('RMSprop: Loss of the ', 59, ' iteration for test:', 0.35239439482244228)
# ('RMSprop: Loss of the ', 60, ' iteration for test:', 0.34102867961433653)
# ('RMSprop: Loss of the ', 61, ' iteration for test:', 0.32988378662727375)
# ('RMSprop: Loss of the ', 62, ' iteration for test:', 0.31896920690533498)
# ('RMSprop: Loss of the ', 63, ' iteration for test:', 0.3082722056166492)
# ('RMSprop: Loss of the ', 64, ' iteration for test:', 0.29780094968668508)
# ('RMSprop: Loss of the ', 65, ' iteration for test:', 0.28754331885264267)
# ('RMSprop: Loss of the ', 66, ' iteration for test:', 0.277508539424833)
# ('RMSprop: Loss of the ', 67, ' iteration for test:', 0.26768265246688683)
# ('RMSprop: Loss of the ', 68, ' iteration for test:', 0.25807874222832239)
# ('RMSprop: Loss of the ', 69, ' iteration for test:', 0.27293761972698904)
# ('RMSprop: Loss of the ', 70, ' iteration for test:', 0.26100090104191248)
# ('RMSprop: Loss of the ', 71, ' iteration for test:', 0.24956590333652701)
# ('RMSprop: Loss of the ', 72, ' iteration for test:', 0.24942689153836928)
# ('RMSprop: Loss of the ', 73, ' iteration for test:', 0.23610437572937309)
# ('RMSprop: Loss of the ', 74, ' iteration for test:', 0.22432246846207221)
# ('RMSprop: Loss of the ', 75, ' iteration for test:', 0.21343441944844432)
# ('RMSprop: Loss of the ', 76, ' iteration for test:', 0.20344123892597804)
# ('RMSprop: Loss of the ', 77, ' iteration for test:', 0.19381791892674546)
# ('RMSprop: Loss of the ', 78, ' iteration for test:', 0.18495000503321843)
# ('RMSprop: Loss of the ', 79, ' iteration for test:', 0.17613841209413195)
# ('RMSprop: Loss of the ', 80, ' iteration for test:', 0.16811498921624179)
# ('RMSprop: Loss of the ', 81, ' iteration for test:', 0.16007669762032992)
# ('RMSprop: Loss of the ', 82, ' iteration for test:', 0.17873412075940528)
# ('RMSprop: Loss of the ', 83, ' iteration for test:', 0.16937693578462151)
# ('RMSprop: Loss of the ', 84, ' iteration for test:', 0.16048891655189051)
# ('RMSprop: Loss of the ', 85, ' iteration for test:', 0.1519649439567374)
# ('RMSprop: Loss of the ', 86, ' iteration for test:', 0.14383253499077672)
# ('RMSprop: Loss of the ', 87, ' iteration for test:', 0.16514680124088335)
# ('RMSprop: Loss of the ', 88, ' iteration for test:', 0.187044867356362)
# ('RMSprop: Loss of the ', 89, ' iteration for test:', 0.17646001819946169)
# ('RMSprop: Loss of the ', 90, ' iteration for test:', 0.16636469362702064)
# ('RMSprop: Loss of the ', 91, ' iteration for test:', 0.15671658070142544)
# ('RMSprop: Loss of the ', 92, ' iteration for test:', 0.17045297344210281)
# ('RMSprop: Loss of the ', 93, ' iteration for test:', 0.16238058121494423)
# ('RMSprop: Loss of the ', 94, ' iteration for test:', 0.15256546484296735)
# ('RMSprop: Loss of the ', 95, ' iteration for test:', 0.1430526968854233)
# ('RMSprop: Loss of the ', 96, ' iteration for test:', 0.13413819796288443)
# ('RMSprop: Loss of the ', 97, ' iteration for test:', 0.12558571721600273)
# ('RMSprop: Loss of the ', 98, ' iteration for test:', 0.11750536847644359)
# ('RMSprop: Loss of the ', 99, ' iteration for test:', 0.10978189579928808)
# ('RMSprop: Loss of the ', 100, ' iteration for test:', 0.102505306696013)
# ('RMSprop: Loss of the ', 101, ' iteration for test:', 0.095542244190397294)
# ('RMSprop: Loss of the ', 102, ' iteration for test:', 0.089014566428000388)
# ('RMSprop: Loss of the ', 103, ' iteration for test:', 0.082767931042184176)
# ('RMSprop: Loss of the ', 104, ' iteration for test:', 0.076926537724529814)
# ('RMSprop: Loss of the ', 105, ' iteration for test:', 0.1021583058571756)
# ('RMSprop: Loss of the ', 106, ' iteration for test:', 0.095584050491419492)
# ('RMSprop: Loss of the ', 107, ' iteration for test:', 0.089291881674210788)
# ('RMSprop: Loss of the ', 108, ' iteration for test:', 0.08335582866996305)
# ('RMSprop: Loss of the ', 109, ' iteration for test:', 0.077679874182975547)
# ('RMSprop: Loss of the ', 110, ' iteration for test:', 0.072354137918911238)
# ('RMSprop: Loss of the ', 111, ' iteration for test:', 0.067232775859388375)
# ('RMSprop: Loss of the ', 112, ' iteration for test:', 0.062502972381095659)
# ('RMSprop: Loss of the ', 113, ' iteration for test:', 0.057887449886159674)
# ('RMSprop: Loss of the ', 114, ' iteration for test:', 0.053682435160027429)
# ('RMSprop: Loss of the ', 115, ' iteration for test:', 0.049591739765477851)
# ('RMSprop: Loss of the ', 116, ' iteration for test:', 0.045838069477908659)
# ('RMSprop: Loss of the ', 117, ' iteration for test:', 0.086319531231811394)
# ('RMSprop: Loss of the ', 118, ' iteration for test:', 0.081438815407517545)
# ('RMSprop: Loss of the ', 119, ' iteration for test:', 0.076715783005309984)
# ('RMSprop: Loss of the ', 120, ' iteration for test:', 0.10638600454312636)
# ('RMSprop: Loss of the ', 121, ' iteration for test:', 0.12511558478715887)
# ('RMSprop: Loss of the ', 122, ' iteration for test:', 0.11518247494674469)
# ('RMSprop: Loss of the ', 123, ' iteration for test:', 0.11004001699230244)
# ('RMSprop: Loss of the ', 124, ' iteration for test:', 0.10240309951634044)
# ('RMSprop: Loss of the ', 125, ' iteration for test:', 0.096268939119966493)
# ('RMSprop: Loss of the ', 126, ' iteration for test:', 0.090023401692371136)
# ('RMSprop: Loss of the ', 127, ' iteration for test:', 0.1029545615059566)
# ('RMSprop: Loss of the ', 128, ' iteration for test:', 0.096177361913520221)
# ('RMSprop: Loss of the ', 129, ' iteration for test:', 0.089733264144461797)
# ('RMSprop: Loss of the ', 130, ' iteration for test:', 0.10889658626004542)
# ('RMSprop: Loss of the ', 131, ' iteration for test:', 0.1276450105266736)
# ('RMSprop: Loss of the ', 132, ' iteration for test:', 0.11903888441652211)
# ('RMSprop: Loss of the ', 133, ' iteration for test:', 0.1225484094944512)
# ('RMSprop: Loss of the ', 134, ' iteration for test:', 0.11376446147188951)
# ('RMSprop: Loss of the ', 135, ' iteration for test:', 0.1054530097878823)
# ('RMSprop: Loss of the ', 136, ' iteration for test:', 0.097817978780670445)
# ('RMSprop: Loss of the ', 137, ' iteration for test:', 0.12906301723592475)
# ('RMSprop: Loss of the ', 138, ' iteration for test:', 0.14691040594165783)
# ('RMSprop: Loss of the ', 139, ' iteration for test:', 0.13594743397083814)
# ('RMSprop: Loss of the ', 140, ' iteration for test:', 0.12580934890352094)
# ('RMSprop: Loss of the ', 141, ' iteration for test:', 0.11622029423094789)
# ('RMSprop: Loss of the ', 142, ' iteration for test:', 0.12502326702106842)
# ('RMSprop: Loss of the ', 143, ' iteration for test:', 0.11582364443693716)
# ('RMSprop: Loss of the ', 144, ' iteration for test:', 0.10957751033408764)
# ('RMSprop: Loss of the ', 145, ' iteration for test:', 0.1013157205306654)
# ('RMSprop: Loss of the ', 146, ' iteration for test:', 0.093642394086986894)
# ('RMSprop: Loss of the ', 147, ' iteration for test:', 0.086401240553712511)
# ('RMSprop: Loss of the ', 148, ' iteration for test:', 0.079678445080312701)
# ('RMSprop: Loss of the ', 149, ' iteration for test:', 0.073352895711375501)
# ('RMSprop: Loss of the ', 150, ' iteration for test:', 0.067472711330550869)
# ('RMSprop: Loss of the ', 151, ' iteration for test:', 0.061982532020355183)
# ('RMSprop: Loss of the ', 152, ' iteration for test:', 0.056819826357269294)
# ('RMSprop: Loss of the ', 153, ' iteration for test:', 0.052152475054031408)
# ('RMSprop: Loss of the ', 154, ' iteration for test:', 0.047472624033762005)
# ('RMSprop: Loss of the ', 155, ' iteration for test:', 0.043879688107817762)
# ('RMSprop: Loss of the ', 156, ' iteration for test:', 0.038902681086861256)
# ('RMSprop: Loss of the ', 157, ' iteration for test:', 0.037237442956088863)
# ('RMSprop: Loss of the ', 158, ' iteration for test:', 0.068161794284240351)
# ('RMSprop: Loss of the ', 159, ' iteration for test:', 0.065118039704733205)
# ('RMSprop: Loss of the ', 160, ' iteration for test:', 0.060300582391798599)
# ('RMSprop: Loss of the ', 161, ' iteration for test:', 0.056876146968597413)
# ('RMSprop: Loss of the ', 162, ' iteration for test:', 0.076647221958690781)
# ('RMSprop: Loss of the ', 163, ' iteration for test:', 0.072274392718986863)
# ('RMSprop: Loss of the ', 164, ' iteration for test:', 0.067844621616278869)
# ('RMSprop: Loss of the ', 165, ' iteration for test:', 0.078489401474118453)
# ('RMSprop: Loss of the ', 166, ' iteration for test:', 0.073600517592103509)
# ('RMSprop: Loss of the ', 167, ' iteration for test:', 0.069037254201367221)
# ('RMSprop: Loss of the ', 168, ' iteration for test:', 0.064622309072561834)
# ('RMSprop: Loss of the ', 169, ' iteration for test:', 0.060488022427208077)
# ('RMSprop: Loss of the ', 170, ' iteration for test:', 0.056497293990611291)
# ('RMSprop: Loss of the ', 171, ' iteration for test:', 0.052776983738930958)
# ('RMSprop: Loss of the ', 172, ' iteration for test:', 0.078596558144363338)
# ('RMSprop: Loss of the ', 173, ' iteration for test:', 0.074203229064338946)
# ('RMSprop: Loss of the ', 174, ' iteration for test:', 0.069852328694301524)
# ('RMSprop: Loss of the ', 175, ' iteration for test:', 0.084331027245144227)
# ('RMSprop: Loss of the ', 176, ' iteration for test:', 0.079238183587750324)
# ('RMSprop: Loss of the ', 177, ' iteration for test:', 0.074718581213638086)
# ('RMSprop: Loss of the ', 178, ' iteration for test:', 0.069852723076746795)
# ('RMSprop: Loss of the ', 179, ' iteration for test:', 0.066049123488365322)
# ('RMSprop: Loss of the ', 180, ' iteration for test:', 0.090449456709049553)
# ('RMSprop: Loss of the ', 181, ' iteration for test:', 0.085800062426541854)
# ('RMSprop: Loss of the ', 182, ' iteration for test:', 0.079381110135623267)
# ('RMSprop: Loss of the ', 183, ' iteration for test:', 0.075284819168731268)
# ('RMSprop: Loss of the ', 184, ' iteration for test:', 0.09352155044428577)
# ('RMSprop: Loss of the ', 185, ' iteration for test:', 0.088412238125918904)
# ('RMSprop: Loss of the ', 186, ' iteration for test:', 0.10900060485825985)
# ('RMSprop: Loss of the ', 187, ' iteration for test:', 0.10155336359297185)
# ('RMSprop: Loss of the ', 188, ' iteration for test:', 0.093950687883106482)
# ('RMSprop: Loss of the ', 189, ' iteration for test:', 0.087380082580168855)
# ('RMSprop: Loss of the ', 190, ' iteration for test:', 0.080797042485893672)
# ('RMSprop: Loss of the ', 191, ' iteration for test:', 0.075063423422628936)
# ('RMSprop: Loss of the ', 192, ' iteration for test:', 0.069284833806601845)
# ('RMSprop: Loss of the ', 193, ' iteration for test:', 0.064398674026581545)
# ('RMSprop: Loss of the ', 194, ' iteration for test:', 0.05915197798722055)
# ('RMSprop: Loss of the ', 195, ' iteration for test:', 0.055158211569836281)
# ('RMSprop: Loss of the ', 196, ' iteration for test:', 0.050429325000846618)
# ('RMSprop: Loss of the ', 197, ' iteration for test:', 0.046966570284569707)
# ('RMSprop: Loss of the ', 198, ' iteration for test:', 0.042858158665289393)
# ('RMSprop: Loss of the ', 199, ' iteration for test:', 0.039940073769609494)
# ('RMSprop: Loss of the ', 200, ' iteration for test:', 0.036163064549039947)
# ('Adam: Loss of the ', 1, ' iteration for test:', 2.0012991314473072)
# ('Adam: Loss of the ', 2, ' iteration for test:', 1.9539235755079762)
# ('Adam: Loss of the ', 3, ' iteration for test:', 1.898968604257357)
# ('Adam: Loss of the ', 4, ' iteration for test:', 1.8389478479057504)
# ('Adam: Loss of the ', 5, ' iteration for test:', 1.7756620007639345)
# ('Adam: Loss of the ', 6, ' iteration for test:', 1.7105726872941072)
# ('Adam: Loss of the ', 7, ' iteration for test:', 1.6448959963821239)
# ('Adam: Loss of the ', 8, ' iteration for test:', 1.5795702264511513)
# ('Adam: Loss of the ', 9, ' iteration for test:', 1.5152557562620286)
# ('Adam: Loss of the ', 10, ' iteration for test:', 1.4523749615255086)
# ('Adam: Loss of the ', 11, ' iteration for test:', 1.3911733724882394)
# ('Adam: Loss of the ', 12, ' iteration for test:', 1.3317760684262068)
# ('Adam: Loss of the ', 13, ' iteration for test:', 1.2742296271107689)
# ('Adam: Loss of the ', 14, ' iteration for test:', 1.2185310212993763)
# ('Adam: Loss of the ', 15, ' iteration for test:', 1.1646445538485108)
# ('Adam: Loss of the ', 16, ' iteration for test:', 1.1125134732632309)
# ('Adam: Loss of the ', 17, ' iteration for test:', 1.0620715823059583)
# ('Adam: Loss of the ', 18, ' iteration for test:', 1.0132535549681674)
# ('Adam: Loss of the ', 19, ' iteration for test:', 0.96600461020612216)
# ('Adam: Loss of the ', 20, ' iteration for test:', 0.92028721304448291)
# ('Adam: Loss of the ', 21, ' iteration for test:', 0.87608308192158812)
# ('Adam: Loss of the ', 22, ' iteration for test:', 0.8333918334422229)
# ('Adam: Loss of the ', 23, ' iteration for test:', 0.79222615409146557)
# ('Adam: Loss of the ', 24, ' iteration for test:', 0.75260586422498421)
# ('Adam: Loss of the ', 25, ' iteration for test:', 0.71455257541723682)
# ('Adam: Loss of the ', 26, ' iteration for test:', 0.6780852208698025)
# ('Adam: Loss of the ', 27, ' iteration for test:', 0.64321730337554595)
# ('Adam: Loss of the ', 28, ' iteration for test:', 0.60995511823131543)
# ('Adam: Loss of the ', 29, ' iteration for test:', 0.57829637461391104)
# ('Adam: Loss of the ', 30, ' iteration for test:', 0.54822909851503343)
# ('Adam: Loss of the ', 31, ' iteration for test:', 0.51973054221757919)
# ('Adam: Loss of the ', 32, ' iteration for test:', 0.4927665647849066)
# ('Adam: Loss of the ', 33, ' iteration for test:', 0.46729186091385594)
# ('Adam: Loss of the ', 34, ' iteration for test:', 0.44325108134596947)
# ('Adam: Loss of the ', 35, ' iteration for test:', 0.42058081987544238)
# ('Adam: Loss of the ', 36, ' iteration for test:', 0.39921211588080968)
# ('Adam: Loss of the ', 37, ' iteration for test:', 0.37907304247430007)
# ('Adam: Loss of the ', 38, ' iteration for test:', 0.36009108675947987)
# ('Adam: Loss of the ', 39, ' iteration for test:', 0.34219504604436474)
# ('Adam: Loss of the ', 40, ' iteration for test:', 0.32531631112722464)
# ('Adam: Loss of the ', 41, ' iteration for test:', 0.30938959747109707)
# ('Adam: Loss of the ', 42, ' iteration for test:', 0.29597977237991507)
# ('Adam: Loss of the ', 43, ' iteration for test:', 0.28320561923707344)
# ('Adam: Loss of the ', 44, ' iteration for test:', 0.27100177628353334)
# ('Adam: Loss of the ', 45, ' iteration for test:', 0.25931317335108295)
# ('Adam: Loss of the ', 46, ' iteration for test:', 0.24809446953245717)
# ('Adam: Loss of the ', 47, ' iteration for test:', 0.23730909004341988)
# ('Adam: Loss of the ', 48, ' iteration for test:', 0.22692807009952062)
# ('Adam: Loss of the ', 49, ' iteration for test:', 0.21692882224174184)
# ('Adam: Loss of the ', 50, ' iteration for test:', 0.2072938662664553)
# ('Adam: Loss of the ', 51, ' iteration for test:', 0.19800958445412994)
# ('Adam: Loss of the ', 52, ' iteration for test:', 0.18906512794658265)
# ('Adam: Loss of the ', 53, ' iteration for test:', 0.18045161800874143)
# ('Adam: Loss of the ', 54, ' iteration for test:', 0.17216170664254252)
# ('Adam: Loss of the ', 55, ' iteration for test:', 0.16418941419335312)
# ('Adam: Loss of the ', 56, ' iteration for test:', 0.15653005103723805)
# ('Adam: Loss of the ', 57, ' iteration for test:', 0.14918002221246143)
# ('Adam: Loss of the ', 58, ' iteration for test:', 0.14479266822820896)
# ('Adam: Loss of the ', 59, ' iteration for test:', 0.140396763928894)
# ...
# ('Adam: Loss of the ', 193, ' iteration for test:', 0.11530876730576659)
# ('Adam: Loss of the ', 194, ' iteration for test:', 0.11524935120093958)
# ('Adam: Loss of the ', 195, ' iteration for test:', 0.11462328457910816)
# ('Adam: Loss of the ', 196, ' iteration for test:', 0.11349180996833684)
# ('Adam: Loss of the ', 197, ' iteration for test:', 0.1134939828195563)
# ('Adam: Loss of the ', 198, ' iteration for test:', 0.11337245758392492)
# ('Adam: Loss of the ', 199, ' iteration for test:', 0.11271061287290643)
# ('Adam: Loss of the ', 200, ' iteration for test:', 0.11156865645624343)
# ('AdaDelta: Loss of the ', 1, ' iteration for test:', 1.9576121547631831)
# ('AdaDelta: Loss of the ', 2, ' iteration for test:', 1.8811074311912204)
# ('AdaDelta: Loss of the ', 3, ' iteration for test:', 1.8078593974703987)
# ('AdaDelta: Loss of the ', 4, ' iteration for test:', 1.738626318847194)
# ('AdaDelta: Loss of the ', 5, ' iteration for test:', 1.6724095858700812)
# ('AdaDelta: Loss of the ', 6, ' iteration for test:', 1.6095457909687771)
# ('AdaDelta: Loss of the ', 7, ' iteration for test:', 1.5490771555799725)
# ('AdaDelta: Loss of the ', 8, ' iteration for test:', 1.4914880281455556)
# ('AdaDelta: Loss of the ', 9, ' iteration for test:', 1.4359033261849319)
# ('AdaDelta: Loss of the ', 10, ' iteration for test:', 1.3829014727552473)
# ('AdaDelta: Loss of the ', 11, ' iteration for test:', 1.3316355261224722)
# ('AdaDelta: Loss of the ', 12, ' iteration for test:', 1.2827400377402702)
# ('AdaDelta: Loss of the ', 13, ' iteration for test:', 1.235370958940478)
# ('AdaDelta: Loss of the ', 14, ' iteration for test:', 1.1902025888979011)
# ('AdaDelta: Loss of the ', 15, ' iteration for test:', 1.1463834144092158)
# ('AdaDelta: Loss of the ', 16, ' iteration for test:', 1.1046203103368792)
# ('AdaDelta: Loss of the ', 17, ' iteration for test:', 1.0640499895180204)
# ('AdaDelta: Loss of the ', 18, ' iteration for test:', 1.0254084180106366)
# ('AdaDelta: Loss of the ', 19, ' iteration for test:', 0.98781868211351531)
# ('AdaDelta: Loss of the ', 20, ' iteration for test:', 0.9520438623682268)
# ('AdaDelta: Loss of the ', 21, ' iteration for test:', 0.91719259608593995)
# ('AdaDelta: Loss of the ', 22, ' iteration for test:', 0.88405374342566356)
# ('AdaDelta: Loss of the ', 23, ' iteration for test:', 0.85172111897254876)
# ('AdaDelta: Loss of the ', 24, ' iteration for test:', 0.82100831795034868)
# ('AdaDelta: Loss of the ', 25, ' iteration for test:', 0.79099416335472816)
# ('AdaDelta: Loss of the ', 26, ' iteration for test:', 0.76251608628421064)
# ('AdaDelta: Loss of the ', 27, ' iteration for test:', 0.73463784940345367)
# ('AdaDelta: Loss of the ', 28, ' iteration for test:', 0.70821990570545135)
# ('AdaDelta: Loss of the ', 29, ' iteration for test:', 0.68231094289648031)
# ('AdaDelta: Loss of the ', 30, ' iteration for test:', 0.65779368204928301)
# ('AdaDelta: Loss of the ', 31, ' iteration for test:', 0.63370175458070832)
# ('AdaDelta: Loss of the ', 32, ' iteration for test:', 0.61093944533413469)
# ('AdaDelta: Loss of the ', 33, ' iteration for test:', 0.58852537144198969)
# ('AdaDelta: Loss of the ', 34, ' iteration for test:', 0.56738472172708865)
# ('AdaDelta: Loss of the ', 35, ' iteration for test:', 0.54652115908745635)
# ('AdaDelta: Loss of the ', 36, ' iteration for test:', 0.52688015811844835)
# ('AdaDelta: Loss of the ', 37, ' iteration for test:', 0.50745050229110422)
# ('AdaDelta: Loss of the ', 38, ' iteration for test:', 0.48919737303148852)
# ('AdaDelta: Loss of the ', 39, ' iteration for test:', 0.47109476153637414)
# ('AdaDelta: Loss of the ', 40, ' iteration for test:', 0.45412701416416879)
# ('AdaDelta: Loss of the ', 41, ' iteration for test:', 0.43725342733852118)
# ('AdaDelta: Loss of the ', 42, ' iteration for test:', 0.42147700523186377)
# ('AdaDelta: Loss of the ', 43, ' iteration for test:', 0.40574245558650657)
# ('AdaDelta: Loss of the ', 44, ' iteration for test:', 0.39107096574727701)
# ('AdaDelta: Loss of the ', 45, ' iteration for test:', 0.37639276787775655)
# ('AdaDelta: Loss of the ', 46, ' iteration for test:', 0.36274678803138011)
# ('AdaDelta: Loss of the ', 47, ' iteration for test:', 0.34904890148596412)
# ('AdaDelta: Loss of the ', 48, ' iteration for test:', 0.33635535647121273)
# ('AdaDelta: Loss of the ', 49, ' iteration for test:', 0.32356779439534022)
# ('AdaDelta: Loss of the ', 50, ' iteration for test:', 0.31175939490778892)
# ('AdaDelta: Loss of the ', 51, ' iteration for test:', 0.29981769176799866)
# ('AdaDelta: Loss of the ', 52, ' iteration for test:', 0.28883242902547651)
# ('AdaDelta: Loss of the ', 53, ' iteration for test:', 0.27767716123968428)
# ('AdaDelta: Loss of the ', 54, ' iteration for test:', 0.26745785167025282)
# ('AdaDelta: Loss of the ', 55, ' iteration for test:', 0.25703420550914596)
# ('AdaDelta: Loss of the ', 56, ' iteration for test:', 0.24752808009694258)
# ('AdaDelta: Loss of the ', 57, ' iteration for test:', 0.23778546175129933)
# ('AdaDelta: Loss of the ', 58, ' iteration for test:', 0.2542357261527215)
# ('AdaDelta: Loss of the ', 59, ' iteration for test:', 0.24347318268311285)
# ('AdaDelta: Loss of the ', 60, ' iteration for test:', 0.23370193960725602)
# ('AdaDelta: Loss of the ', 61, ' iteration for test:', 0.22373456405203593)
# ('AdaDelta: Loss of the ', 62, ' iteration for test:', 0.21473280754457907)
# ('AdaDelta: Loss of the ', 63, ' iteration for test:', 0.21139535062601827)
# ('AdaDelta: Loss of the ', 64, ' iteration for test:', 0.20274383405721286)
# ('AdaDelta: Loss of the ', 65, ' iteration for test:', 0.1938440437420435)
# ('AdaDelta: Loss of the ', 66, ' iteration for test:', 0.18588690962812882)
# ('AdaDelta: Loss of the ', 67, ' iteration for test:', 0.17764601649016665)
# ('AdaDelta: Loss of the ', 68, ' iteration for test:', 0.17032728991305973)
# ('AdaDelta: Loss of the ', 69, ' iteration for test:', 0.18193772840251893)
# ('AdaDelta: Loss of the ', 70, ' iteration for test:', 0.1734062338031119)
# ('AdaDelta: Loss of the ', 71, ' iteration for test:', 0.16532907659508403)
# ('AdaDelta: Loss of the ', 72, ' iteration for test:', 0.15793193649555709)
# ('AdaDelta: Loss of the ', 73, ' iteration for test:', 0.15068242909893823)
# ('AdaDelta: Loss of the ', 74, ' iteration for test:', 0.14394612929802361)
# ('AdaDelta: Loss of the ', 75, ' iteration for test:', 0.13728387496379071)
# ('AdaDelta: Loss of the ', 76, ' iteration for test:', 0.13109945354726404)
# ('AdaDelta: Loss of the ', 77, ' iteration for test:', 0.12496045116508885)
# ('AdaDelta: Loss of the ', 78, ' iteration for test:', 0.11927891428830585)
# ('AdaDelta: Loss of the ', 79, ' iteration for test:', 0.13511403304470229)
# ('AdaDelta: Loss of the ', 80, ' iteration for test:', 0.14733074340268829)
# ('AdaDelta: Loss of the ', 81, ' iteration for test:', 0.13995918555740888)
# ('AdaDelta: Loss of the ', 82, ' iteration for test:', 0.13312276625109049)
# ('AdaDelta: Loss of the ', 83, ' iteration for test:', 0.12637479164273396)
# ('AdaDelta: Loss of the ', 84, ' iteration for test:', 0.12013746762267993)
# ('AdaDelta: Loss of the ', 85, ' iteration for test:', 0.11396120460256894)
# ('AdaDelta: Loss of the ', 86, ' iteration for test:', 0.10827342046273458)
# ('AdaDelta: Loss of the ', 87, ' iteration for test:', 0.10262157519539265)
# ('AdaDelta: Loss of the ', 88, ' iteration for test:', 0.097438159859913012)
# ('AdaDelta: Loss of the ', 89, ' iteration for test:', 0.092267631766398323)
# ('AdaDelta: Loss of the ', 90, ' iteration for test:', 0.087547421712813184)
# ('AdaDelta: Loss of the ', 91, ' iteration for test:', 0.082818935262424481)
# ('AdaDelta: Loss of the ', 92, ' iteration for test:', 0.07852441559140623)
# ('AdaDelta: Loss of the ', 93, ' iteration for test:', 0.074202171347386214)
# ('AdaDelta: Loss of the ', 94, ' iteration for test:', 0.07029913722156704)
# ('AdaDelta: Loss of the ', 95, ' iteration for test:', 0.06635048406188189)
# ('AdaDelta: Loss of the ', 96, ' iteration for test:', 0.062807723865579118)
# ('AdaDelta: Loss of the ', 97, ' iteration for test:', 0.059202853252509437)
# ('AdaDelta: Loss of the ', 98, ' iteration for test:', 0.0559918539622161)
# ('AdaDelta: Loss of the ', 99, ' iteration for test:', 0.052703516450623329)
# ('AdaDelta: Loss of the ', 100, ' iteration for test:', 0.049798191176208408)
# ('AdaDelta: Loss of the ', 101, ' iteration for test:', 0.046801434948478847)
# ('AdaDelta: Loss of the ', 102, ' iteration for test:', 0.044177872307566597)
# ('AdaDelta: Loss of the ', 103, ' iteration for test:', 0.068384705482028491)
# ('AdaDelta: Loss of the ', 104, ' iteration for test:', 0.065022607909373087)
# ('AdaDelta: Loss of the ', 105, ' iteration for test:', 0.061570039024105794)
# ('AdaDelta: Loss of the ', 106, ' iteration for test:', 0.058499349412638665)
# ('AdaDelta: Loss of the ', 107, ' iteration for test:', 0.055325726631087285)
# ('AdaDelta: Loss of the ', 108, ' iteration for test:', 0.052525580987163631)
# ('AdaDelta: Loss of the ', 109, ' iteration for test:', 0.049610833420944994)
# ('AdaDelta: Loss of the ', 110, ' iteration for test:', 0.069728571149051247)
# ('AdaDelta: Loss of the ', 111, ' iteration for test:', 0.066083313036998839)
# ('AdaDelta: Loss of the ', 112, ' iteration for test:', 0.062833811529268563)
# ('AdaDelta: Loss of the ', 113, ' iteration for test:', 0.059484059242705251)
# ('AdaDelta: Loss of the ', 114, ' iteration for test:', 0.056520915140334388)
# ('AdaDelta: Loss of the ', 115, ' iteration for test:', 0.053445192172669978)
# ('AdaDelta: Loss of the ', 116, ' iteration for test:', 0.050747651693043433)
# ('AdaDelta: Loss of the ', 117, ' iteration for test:', 0.047925926175542491)
# ('AdaDelta: Loss of the ', 118, ' iteration for test:', 0.045474623440352503)
# ('AdaDelta: Loss of the ', 119, ' iteration for test:', 0.042888197089026699)
# ('AdaDelta: Loss of the ', 120, ' iteration for test:', 0.066488655938772789)
# ('AdaDelta: Loss of the ', 121, ' iteration for test:', 0.082801534214221859)
# ('AdaDelta: Loss of the ', 122, ' iteration for test:', 0.078979957950366525)
# ('AdaDelta: Loss of the ', 123, ' iteration for test:', 0.075067820298757484)
# ('AdaDelta: Loss of the ', 124, ' iteration for test:', 0.071568585200013232)
# ('AdaDelta: Loss of the ', 125, ' iteration for test:', 0.06796491064664123)
# ('AdaDelta: Loss of the ', 126, ' iteration for test:', 0.064764101325686205)
# ('AdaDelta: Loss of the ', 127, ' iteration for test:', 0.061445841410475273)
# ('AdaDelta: Loss of the ', 128, ' iteration for test:', 0.077938334531926737)
# ('AdaDelta: Loss of the ', 129, ' iteration for test:', 0.07398705413967957)
# ('AdaDelta: Loss of the ', 130, ' iteration for test:', 0.087018043122475158)
# ('AdaDelta: Loss of the ', 131, ' iteration for test:', 0.082531043786845906)
# ('AdaDelta: Loss of the ', 132, ' iteration for test:', 0.078497014390014413)
# ('AdaDelta: Loss of the ', 133, ' iteration for test:', 0.088728059961492786)
# ('AdaDelta: Loss of the ', 134, ' iteration for test:', 0.084250264300445132)
# ('AdaDelta: Loss of the ', 135, ' iteration for test:', 0.079757455781838293)
# ('AdaDelta: Loss of the ', 136, ' iteration for test:', 0.0756314481017136)
# ('AdaDelta: Loss of the ', 137, ' iteration for test:', 0.071573651620231979)
# ('AdaDelta: Loss of the ', 138, ' iteration for test:', 0.067820532801260353)
# ('AdaDelta: Loss of the ', 139, ' iteration for test:', 0.064127083547825037)
# ('AdaDelta: Loss of the ', 140, ' iteration for test:', 0.060720067030331948)
# ('AdaDelta: Loss of the ', 141, ' iteration for test:', 0.057360746062736646)
# ('AdaDelta: Loss of the ', 142, ' iteration for test:', 0.054270586615985002)
# ('AdaDelta: Loss of the ', 143, ' iteration for test:', 0.070926593709234181)
# ('AdaDelta: Loss of the ', 144, ' iteration for test:', 0.067173992811852379)
# ('AdaDelta: Loss of the ', 145, ' iteration for test:', 0.063463882981658393)
# ('AdaDelta: Loss of the ', 146, ' iteration for test:', 0.060108380330562074)
# ('AdaDelta: Loss of the ', 147, ' iteration for test:', 0.056703081686838144)
# ('AdaDelta: Loss of the ', 148, ' iteration for test:', 0.053673672996985264)
# ('AdaDelta: Loss of the ', 149, ' iteration for test:', 0.079057641879426696)
# ('AdaDelta: Loss of the ', 150, ' iteration for test:', 0.074889863890252234)
# ('AdaDelta: Loss of the ', 151, ' iteration for test:', 0.070703891827061535)
# ('AdaDelta: Loss of the ', 152, ' iteration for test:', 0.066930379346880758)
# ('AdaDelta: Loss of the ', 153, ' iteration for test:', 0.085592051084614387)
# ('AdaDelta: Loss of the ', 154, ' iteration for test:', 0.097083642106424117)
# ('AdaDelta: Loss of the ', 155, ' iteration for test:', 0.09135602248863034)
# ('AdaDelta: Loss of the ', 156, ' iteration for test:', 0.086139721446196083)
# ('AdaDelta: Loss of the ', 157, ' iteration for test:', 0.08097789890576132)
# ('AdaDelta: Loss of the ', 158, ' iteration for test:', 0.076301622538270483)
# ('AdaDelta: Loss of the ', 159, ' iteration for test:', 0.08545700337504103)
# ('AdaDelta: Loss of the ', 160, ' iteration for test:', 0.080413308956004292)
# ('AdaDelta: Loss of the ', 161, ' iteration for test:', 0.075426479165084312)
# ('AdaDelta: Loss of the ', 162, ' iteration for test:', 0.070929815161905344)
# ('AdaDelta: Loss of the ', 163, ' iteration for test:', 0.066461416648791516)
# ('AdaDelta: Loss of the ', 164, ' iteration for test:', 0.088714877068186093)
# ('AdaDelta: Loss of the ', 165, ' iteration for test:', 0.083231638452317819)
# ('AdaDelta: Loss of the ', 166, ' iteration for test:', 0.078193198544043677)
# ('AdaDelta: Loss of the ', 167, ' iteration for test:', 0.091930956394409707)
# ('AdaDelta: Loss of the ', 168, ' iteration for test:', 0.085038882052758294)
# ('AdaDelta: Loss of the ', 169, ' iteration for test:', 0.08124831539965606)
# ('AdaDelta: Loss of the ', 170, ' iteration for test:', 0.093068324647731973)
# ('AdaDelta: Loss of the ', 171, ' iteration for test:', 0.088701868439253706)
# ('AdaDelta: Loss of the ', 172, ' iteration for test:', 0.081585857692158856)
# ('AdaDelta: Loss of the ', 173, ' iteration for test:', 0.077909556508338182)
# ('AdaDelta: Loss of the ', 174, ' iteration for test:', 0.071357340332891789)
# ('AdaDelta: Loss of the ', 175, ' iteration for test:', 0.068309222397020503)
# ('AdaDelta: Loss of the ', 176, ' iteration for test:', 0.085713244616355239)
# ('AdaDelta: Loss of the ', 177, ' iteration for test:', 0.10246657849389375)
# ('AdaDelta: Loss of the ', 178, ' iteration for test:', 0.094118265790651995)
# ('AdaDelta: Loss of the ', 179, ' iteration for test:', 0.089780512375666616)
# ('AdaDelta: Loss of the ', 180, ' iteration for test:', 0.082207508182488911)
# ('AdaDelta: Loss of the ', 181, ' iteration for test:', 0.078657606236477509)
# ('AdaDelta: Loss of the ', 182, ' iteration for test:', 0.08935609827028887)
# ('AdaDelta: Loss of the ', 183, ' iteration for test:', 0.085358009086099904)
# ('AdaDelta: Loss of the ', 184, ' iteration for test:', 0.077895309347522507)
# ('AdaDelta: Loss of the ', 185, ' iteration for test:', 0.074622413072388691)
# ('AdaDelta: Loss of the ', 186, ' iteration for test:', 0.067754671560880705)
# ('AdaDelta: Loss of the ', 187, ' iteration for test:', 0.065133215394047012)
# ('AdaDelta: Loss of the ', 188, ' iteration for test:', 0.078805194375446336)
# ('AdaDelta: Loss of the ', 189, ' iteration for test:', 0.075547182872278462)
# ('AdaDelta: Loss of the ', 190, ' iteration for test:', 0.068520853253914743)
# ('AdaDelta: Loss of the ', 191, ' iteration for test:', 0.065925385651987467)
# ('AdaDelta: Loss of the ', 192, ' iteration for test:', 0.059440414399189748)
# ('AdaDelta: Loss of the ', 193, ' iteration for test:', 0.057440120329322178)
# ('AdaDelta: Loss of the ', 194, ' iteration for test:', 0.076594931750989484)
# ('AdaDelta: Loss of the ', 195, ' iteration for test:', 0.073568002206108873)
# ('AdaDelta: Loss of the ', 196, ' iteration for test:', 0.066532517823141263)
# ('AdaDelta: Loss of the ', 197, ' iteration for test:', 0.095214052805040375)
# ('AdaDelta: Loss of the ', 198, ' iteration for test:', 0.087109429113643222)
# ('AdaDelta: Loss of the ', 199, ' iteration for test:', 0.097240364857003894)
# ('AdaDelta: Loss of the ', 200, ' iteration for test:', 0.088915002725766384)
